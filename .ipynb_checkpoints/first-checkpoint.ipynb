# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Feb 12 19:18:39 2018

@author: Nagasudhir
"""

# import the pandas module into a variable called pd
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as plticker
import seaborn as sns
import numpy as np
import datetime
# %matplotlib notebook
date_base = datetime.datetime.strptime("01/01/1900 00:00:00", "%d/%m/%Y %H:%M:%S")

    
# import excel
df = pd.read_excel('demand.xlsx', \
                   sheet_name='Sheet1', skiprows=3, usecols=range(0, 12), skip_footer=5\
                   )

#df.boxplot()
dates = []
for i in range(df.shape[0]):
    if(i%24 == 0):
        curr_date = date_base + datetime.timedelta(days=int(df.iloc[i,0])-2, hours = 1)
        dates.append(curr_date)
    else:
        dates.append(curr_date + datetime.timedelta(hours=int(df.iloc[i,0])-1))

df.index = dates

df = df.drop(df.columns[[0,1]], axis=1)

daily_max_hrs = df.groupby(df.index.date).apply(lambda x: x.idxmax())

daily_max_vals = df.groupby(df.index.date).apply(lambda x: x.max())

#plt.gca().xaxis.set_minor_locator(plticker.MultipleLocator(base=1))
plt.plot(daily_max_hrs.iloc[:,5], daily_max_vals.iloc[:,5], 'o-')
for i in range(daily_max_vals.shape[0]):
    plt.gca().annotate(daily_max_hrs.iloc[i,5].hour, (daily_max_hrs.iloc[i,5],daily_max_vals.iloc[i,5]))
plt.ylabel('Mah daily max demand')
plt.title('Demands')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Out:
#                       MAH.+L.S       MAH.         GOA   dd  Dnh        ESIL  \
# 2018-01-01 01:00:00  13536.792  13536.792  354.108333  236  670  566.841493
# 2018-01-01 02:00:00  13364.768  13364.768  354.908333  229  661  640.264840
# 2018-01-01 03:00:00  13331.768  13331.768  343.908333  229  658  682.742871
# 2018-01-01 04:00:00  13426.744  13426.744  333.908333  229  659  683.025843
# 2018-01-01 05:00:00  13897.280  13897.280  325.158333  227  651  671.445694
#
#                       GUJ.       MP     CHG        WR MET
# 2018-01-01 01:00:00  10710  7620.99  2500.0  36194.731827
# 2018-01-01 02:00:00  10351  7486.29  2539.0  35626.231173
# 2018-01-01 03:00:00  10237  7519.66  2461.0  35463.079204
# 2018-01-01 04:00:00  10146  7464.00  2446.0  35387.678177
# 2018-01-01 05:00:00  10225  7615.14  2541.0  36153.024027
